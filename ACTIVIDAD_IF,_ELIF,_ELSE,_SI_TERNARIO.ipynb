# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaisa290/PROGCOM-A/blob/main/ACTIVIDAD_IF%2C_ELIF%2C_ELSE%2C_SI_TERNARIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###5

# %%
#resuelva una ecuación cuadrática (ax² + bx + c = 0) (IF-ELIF-ELSE)
import math
a = float(input("Ingrese el valor de a: "))
b = float(input("Ingrese el valor de b: "))
c = float(input("Ingrese el valor de c: "))
if a==0:
  print("El valor de 'a' no puede ser cero en la ecuacion")
else:
  discriminante= b**2-4*a*c
if discriminante > 0:
  x1=(-b + math.sqrt(discriminante)) / (2*a)
  x2=(-b - math.sqrt(discriminante)) / (2*a)
  print("las soluciones de la ecuación son:")
  print("x1 =", x1)
  print("x2 =", x2)

elif discriminante == 0:
    x=-b / (2*a)
    print(f" la unica solución de la ecuación es:")
    print("x=", x)

else:
      print("la ecuación no tiene soluciones en los reales, su discriminate es negativo ")
# Out:
# Ingrese el valor de a: 3
# Ingrese el valor de b: 9
# Ingrese el valor de c: 6
# las soluciones de la ecuación son:
# x1 = -1.0
# x2 = -2.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# /******************************************************************************
#
#                             Online Java Compiler.
#                 Code, Compile, Run and Debug java program online.
# Write your code in this editor and press "Run" button to execute it.
#
# *******************************************************************************/
#
# import java.util.*;
# public class Main
# {
# 	public static void main(String[] args){
#         Scanner Leer = new Scanner(System.in);
#
#         System.out.println("Ecuación cuadrática ax^2 + bx + c = 0");
#
#         System.out.print("Ingrese el valor de a: ");
#         double a = Leer.nextDouble();
#
#         System.out.print("Ingrese el valor de b: ");
#         double b = Leer.nextDouble();
#
#         System.out.print("Ingrese el valor de c: ");
#         double c = Leer.nextDouble();
#
#         if (a == 0) {
#             System.out.println("El valor de 'a' no puede ser cero en la ecuación");
#         } else {
#
#             double discriminante = (b * b) - (4 * a * c);
#
#             if (discriminante > 0) {
#
#                 double x1 = (-b + Math.sqrt(discriminante)) / (2 * a);
#                 double x2 = (-b - Math.sqrt(discriminante)) / (2 * a);
#
#                 System.out.println("Las soluciones son:");
#                 System.out.println("x1 = " + x1);
#                 System.out.println("x2 = " + x2);}
#             else if (discriminante == 0) {double x = -b / (2 * a);
#                 System.out.println("La única solución es:");
#                 System.out.println("x = " + x);  }
#
#             else {System.out.println("No tiene soluciones reales");}
#         }
#
#
# }}
#
# ```

# %%
#resuelva una ecuación cuadrática (ax² + bx + c = 0) (IF-ELSE)
import math

print("Ecuación cuadrática ax^2 + bx + c = 0")

a = float(input("Ingrese a: "))
b = float(input("Ingrese b: "))
c = float(input("Ingrese c: "))
if a == 0:
    print("No es una ecuación cuadrática")
else:
    d = b*b - 4*a*c
    if d < 0:
        print("No tiene soluciones reales")
    else:
        x1 = (-b + math.sqrt(d)) / (2*a)
        x2 = (-b - math.sqrt(d)) / (2*a)
        print("Las soluciones son:")
        print("x1 =", x1)
        print("x2 =", x2)
# Out:
# Ecuación cuadrática ax^2 + bx + c = 0
# Ingrese a: 8
# Ingrese b: 4
# Ingrese c: 2
# No tiene soluciones reales

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
#
# import java.util.*;
# public class Main
# {
# 	public static void main(String[] args){
#         Scanner Leer = new Scanner(System.in);
#
#         System.out.println("Ecuación cuadrática ax^2 + bx + c = 0");
#
#         System.out.print("Ingrese el valor de a: ");
#         double a = Leer.nextDouble();
#
#         System.out.print("Ingrese el valor de b: ");
#         double b = Leer.nextDouble();
#
#         System.out.print("Ingrese el valor de c: ");
#         double c = Leer.nextDouble();
#
#         if (a == 0) {
#             System.out.println("El valor de 'a' no puede ser cero en la ecuación");
#         } else {
#
#             double discriminante = (b * b) - (4 * a * c);
#
#         if (a == 0) {
#             System.out.println("No es una ecuación cuadrática");
#         } else {double d = (b * b) - (4 * a * c);
#
#             if (d < 0) {System.out.println("No tiene soluciones reales");}
#             else {double x1 = (-b + Math.sqrt(d)) / (2 * a);double x2 = (-b - Math.sqrt(d)) / (2 * a);
#
#                 System.out.println("Las soluciones son:");
#                 System.out.println("x1 = " + x1);
#                 System.out.println("x2 = " + x2);
#             }
#         }
#         }
#
#
# }}
# ```

# %%
#resuelva una ecuación cuadrática (ax² + bx + c = 0) (SI TERNARIO)
import math

print("Ecuación cuadrática ax^2 + bx + c = 0")

a = float(input("Ingrese a: "))
b = float(input("Ingrese b: "))
c = float(input("Ingrese c: "))

resp= "No es una ecuación cuadrática" if a == 0 else "No tiene soluciones reales" if d < 0 else "Las soluciones son:"
print(resp)
# Out:
# Ecuación cuadrática ax^2 + bx + c = 0
# Ingrese a: 9
# Ingrese b: 5
# Ingrese c: 8
# No tiene soluciones reales

# %% [markdown]
# ###6

# %%
# 6.Determina si un número es par o impar (IF-ELIF-ELSE)
numero = int(input("Ingrese un número: "))
if numero % 2 == 0:
    print(f"El número {numero} es par")
else:
    if numero % 2 != 0:
        print(f"El número {numero} es impar")
# Out:
# Ingrese un número: 60
# El número 60 es par

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# import java.util.*;
# public class Main
# {
# 	public static void main(String[] args){
#         Scanner Leer = new Scanner(System.in);
#
#         System.out.print("Ingrese un número: ");
#         int numero = Leer.nextInt();
#
#         if (numero % 2 == 0) {System.out.println("El número es par");}
#         else if (numero % 2 != 0) { System.out.println("El número es impar"); }
#         }
#     }
#
# ```

# %%
# 6.Determina si un número es par o impar (IF-ELSE)
numero = int(input("Ingrese un número: "))
if numero % 2 == 0:
    print(f"El número {numero} es par")
else:
    print(f"El número {numero} es impar")
# Out:
# Ingrese un número: 9
# El número 9 es impar

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# import java.util.*;
# public class Main
# {
# 	public static void main(String[] args){
#         Scanner Leer = new Scanner(System.in);
#
#         System.out.print("Ingrese un número: ");
#         int numero = Leer.nextInt();
#
#         if (numero % 2 == 0) {System.out.println("El número es par");}
#         else {System.out.println("El número es impar");}
#         }
#     }
# ```

# %%
# 7. Determina si un número es par o impar (SI TERNARIO)
numero = int(input("Ingrese un número: "))
resp= "El número es par" if numero % 2 == 0 else "El número es impar"
print(resp)
# Out:
# Ingrese un número: 56
# El número es par

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# import java.util.*;
# public class Main
# {
# 	public static void main(String[] args){
#         Scanner Leer = new Scanner(System.in);
#
#         System.out.print("Ingrese un número: ");
#         int numero = Leer.nextInt();
#
#         String resp = (numero % 2 == 0) ? "El número es par" : "El número es impar";
#
#         System.out.println(resp);
#     }}
#
# ```

# %% [markdown]
# ###7

# %%
# 7. Determina si es un año bisiesto (IF-ELIF-ELSE)
año=int(input("Ingrese el año:"))
if año % 4 ==0:
  print("El año ingresado es bisiesto")
elif año % 400 ==0:
  print("El año es bisiesto")
else:
  print(f"El año ingresado {año} no es bisiesto")
# Out:
# ingrese el año:2026
# el año ingresado 2026 no es bisiesto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# import java.util.*;
# public class Main
# {
# 	public static void main(String[] args){
#         Scanner Leer = new Scanner(System.in);
#
#         System.out.print("Ingrese el año: ");
#         int año = Leer.nextInt();
#
#         if (año % 400 == 0) {System.out.println("El año es bisiesto"); }
#         else if (año % 4 == 0 && año % 100 != 0) { System.out.println("El año ingresado es bisiesto"); }
#         else { System.out.println("El año ingresado no es bisiesto"); }
#     }}```

# %%
# 7. Determina si es un año bisiesto (IF-ELSE)
año=int(input("Ingrese el año:"))
if año % 4 ==0:
  print("El año ingresado es bisiesto")
else:
  if año % 400 ==0:
    print("El año es bisiesto")
  else:
    print(f"El año ingresado {año} no es bisiesto")
# Out:
# Ingrese el año:2026
# El año ingresado 2026 no es bisiesto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# import java.util.*;
# public class Main
# {
# 	public static void main(String[] args){
#         Scanner Leer = new Scanner(System.in);
#
#         System.out.print("Ingrese el año: ");
#         int año = Leer.nextInt();
#
#         if (año % 4 == 0) {System.out.println("El año ingresado es bisiesto");}
#         else
#         if (año % 400 == 0) {System.out.println("El año es bisiesto");}
#         else { System.out.println("El año ingresado no es bisiesto");}
# }}
# ```

# %%
# 7. Determina si es un año bisiesto (SI TERNARIO)
resp= "El año ingresado es bisiesto" if año % 4 ==0 else "El año es bisiesto" if año % 400 ==0 else "El año ingresado no es bisiesto"
print(resp)
# Out:
# El año ingresado no es bisiesto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# import java.util.*;
# public class Main
# {
# 	public static void main(String[] args){
#         Scanner Leer = new Scanner(System.in);
#
#         System.out.print("Ingrese el año: ");
#         int año = Leer.nextInt();
#
#        System.out.println (año % 4 == 0 ? "El año ingresado es bisiesto" : año % 400 == 0 ? "El año es bisiesto"
#        : "El año ingresado no es bisiesto");
# }}
# ```

# %% [markdown]
# ###8

# %%
#8 pertenece o no a la tercera edad (IF-ELIF-ELSE)
nombre = input("Por favor, ingresa tu nombre: ")
edad = int(input("Ingresa tu edad: "))

if edad >= 70:
    print(f"Hola {nombre}, perteneces a la tercera edad.")
    print("Tienes prioridad en la fila.")
elif edad >= 18:
    print(f"Hola {nombre}. Usted es mayor de edad, por favor haga la fila regular.")

else:
    print(f"Hola {nombre}. Eres menor de edad, por favor espera a tu tutor.")
# Out:
# Por favor, ingresa tu nombre: Vianny
# Ingresa tu edad: 17
# Hola Vianny. Eres menor de edad, por favor espera a tu tutor.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
#
# import java.util.*;
# public class Main
# {
# 	public static void main(String[] args){
#         Scanner Leer = new Scanner(System.in);
#
#         System.out.print("Por favor, ingresa tu edad: ");
#         int edad = Leer.nextInt();
#
#         if (edad >= 70) { System.out.println("Hola, perteneces a la tercera edad. Tienes prioridad en la fila.");}
#         else if (edad >= 18) {System.out.println("Hola, Usted es mayor de edad, por favor haga la fila regular.");}
#         else {System.out.println("Hola, Eres menor de edad, por favor espera a tu tutor.");}
# }}
# ```

# %%
#8 pertenece o no a la tercera edad (IF-ELSE)
nombre = input("Ingresa tu nombre: ")
edad = int(input("Ingresa tu edad: "))

if edad >= 70:
    print(f"Bienvenido/a {nombre}.")
    print("Usted tiene prioridad en la fila por pertenecer a la tercera edad.")
else:
    print(f"Hola {nombre}. Por favor, espere su turno en la fila general.")
# Out:
# Ingresa tu nombre: Geraldine
# Ingresa tu edad: 71
# Bienvenido/a Geraldine.
# Usted tiene prioridad en la fila por pertenecer a la tercera edad.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# import java.util.*;
# public class Main
# {
# 	public static void main(String[] args){
#         Scanner Leer = new Scanner(System.in);
#
#         System.out.print("Por favor, ingresa tu edad: ");
#         int edad = Leer.nextInt();
#
#         if (edad >= 70) { System.out.println("Bienvenido/a, Usted tiene prioridad en la fila por pertenecer a la tercera edad.");}
#         else {System.out.println("Hola, Por favor, espere su turno en la fila general.");}
# }}```

# %%
#8 pertenece o no a la tercera edad (SI TERNARIO)
edad = int(input("Ingresa tu edad: "))
resp="Usted tiene prioridad en la fila por pertenecer a la tercera edad."if edad >= 70 else "Por favor, espere su turno en la fila general."
print(resp)
# Out:
# Ingresa tu edad: 80
# Usted tiene prioridad en la fila por pertenecer a la tercera edad.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# import java.util.*;
# public class Main
# {
# 	public static void main(String[] args){
#         Scanner Leer = new Scanner(System.in);
#
#         System.out.println("Ingresa tu edad: ");
#         int edad = Leer.nextInt();
#
#
#         System.out.println(edad >= 70? "Usted tiene prioridad en la fila por pertenecer a la tercera edad."
#         : "Por favor, espere su turno en la fila general.");
#
# }}
# ```
#
# ---

# %% [markdown]
# ###9

# %%
#compare tres números y muestre el mayor.(IF-ELIF-ELSE)
numero1 = float(input("Ingresa el primer número: "))
numero2 = float(input("Ingresa el segundo número: "))
numero3 = float(input("Ingresa el tercer número: "))

if numero1 > numero2 and numero1 > numero3:
    print("El numero mayor es:", numero1)
elif numero2 > numero1 and numero2 > numero3:
    print("El numero mayor es:", numero2)
elif numero3 > numero1 and numero3 > numero2:
    print("El número mayor es:", numero3)
else:
    print("Hay numeros iguales o los tres son iguales")
# Out:
# Ingresa el primer número: 9
# Ingresa el segundo número: 8
# Ingresa el tercer número: 4
# El numero mayor es: 9.0

# %%
#compare tres números y muestre el mayor.(IF-ELSE)
numero1 = float(input("Ingresa el primer número: "))
numero2 = float(input("Ingresa el segundo número: "))
numero3 = float(input("Ingresa el tercer número: "))

mayor = numero1

if numero2 > mayor:
    mayor = numero2
else:
    mayor = mayor

if numero3 > mayor:
    mayor = numero3
else:
    mayor = mayor
print("El número mayor es:", mayor)
# Out:
# Ingresa el primer número: 7
# Ingresa el segundo número: 13
# Ingresa el tercer número: 6
# El número mayor es: 13.0

# %%
#compare tres números y muestre el mayor. ( IF TERNARIO))
numero1 = float(input("Ingrese el primer número: "))
numero2 = float(input("Ingrese el segundo número: "))
numero3 = float(input("Ingrese el tercer número: "))

mayor = numero1 if numero1 > numero2 else numero2
mayor = mayor if mayor > numero3 else numero3

print("El número mayor es:", mayor)
# Out:
# Ingrese el primer número: 5
# Ingrese el segundo número: 70
# Ingrese el tercer número: 35
# El número mayor es: 70.0

# %% [markdown]
# ###10

# %%
#determine si un triángulo es equilátero, isósceles o escaleno según sus lados. (IF-ELIF-ELSE)
lado1=int(input("Ingrese el primer lado del triangulo: "))
lado2=int(input("Ingrese el segundo lado del triangulo: "))
lado3=int(input("Ingrese el tercer lado del triangulo: "))
if lado1==lado2==lado3:
  print("Es un triangulo equilatero")
elif lado1==lado2 or lado1==lado3 or lado2==lado3:
  print("Es un triangulo isoceles")
else:
  print("Es un triangulo escaleno")
# Out:
# Ingrese el primer lado del triangulo: 9
# Ingrese el segundo lado del triangulo: 4
# Ingrese el tercer lado del triangulo: 9
# Es un triangulo isoceles

# %%
#determine si un triángulo es equilátero, isósceles o escaleno según sus lados. (IF-ELSE)
lado1=int(input("Ingrese el primer lado del triangulo: "))
lado2=int(input("Ingrese el segundo lado del triangulo: "))
lado3=int(input("Ingrese el tercer lado del triangulo: "))
if lado1==lado2==lado3:
  print("Es un triangulo equilatero")
else:
  if lado1==lado2 or lado1==lado3 or lado2==lado3:
    print("Es un triangulo isoceles")
  else:
    print("Es un triangulo escaleno")
# Out:
# Ingrese el primer lado del triangulo: 3
# Ingrese el segundo lado del triangulo: 6
# Ingrese el tercer lado del triangulo: 4
# Es un triangulo escaleno

# %%
#determine si un triángulo es equilátero, isósceles o escaleno según sus lados. (SI TERNARIO)
lado1=int(input("Ingrese el primer lado del triangulo: "))
lado2=int(input("Ingrese el segundo lado del triangulo: "))
lado3=int(input("Ingrese el tercer lado del triangulo: "))

resp="Es un triangulo equilatero" if lado1==lado2==lado3 else "Es un triangulo isoceles" if lado1==lado2 or lado1==lado3 or lado2==lado3 else "Es un triangulo escaleno"
print(resp)
# Out:
# Ingrese el primer lado del triangulo: 6
# Ingrese el segundo lado del triangulo: 6
# Ingrese el tercer lado del triangulo: 3
# Es un triangulo isoceles

# %% [markdown]
# ###11

# %%
#calcule el índice de masa corporal (IMC) y determine la categoría (bajo peso, normal, sobrepeso, obesidad).(IF-ELIF-ELSE)
peso=float(input("Ingrese su peso kg: "))
altura=float(input("Ingrese su estatura m: "))
imc=peso/(altura**2)
print(f"Este es su IMC {imc:.2f}")
if imc<18.5:
  print("Tiene bajo peso")
elif 18.5<imc<24.9:
  print("Tiene peso normal")
elif 25<imc<29.9:
  print("Tiene sobrepeso")
else:
  print("Tiene obesidad")
# Out:
# Ingrese su peso kg: 50
# Ingrese su estatura m: 1.60
# Este es su IMC 19.53
# Tiene peso normal

# %%
#calcule el índice de masa corporal (IMC) y determine la categoría (bajo peso, normal, sobrepeso, obesidad).(IF-ELSE)
peso=float(input("Ingrese su peso kg: "))
altura=float(input("Ingrese su estatura m: "))
imc=peso/(altura**2)
print(f"Este es su IMC {imc:.2f}")
if imc<18.5:
  print("Tiene bajo peso")
else:
  if 18.5<imc<24.9:
    print("Tiene peso normal")
  else:
    if 25<imc<29.9:
      print("Tiene sobrepeso")
    else:
      print("Tiene obesidad")
# Out:
# Ingrese su peso kg: 90
# Ingrese su estatura m: 1.75
# Este es su IMC 29.39
# Tiene sobrepeso

# %%
#calcule el índice de masa corporal (IMC) y determine la categoría (bajo peso, normal, sobrepeso, obesidad).(SI TERNARIO)
peso=float(input("Ingrese su peso kg: "))
altura=float(input("Ingrese su estatura m: "))
imc=peso/(altura**2)
print(f"Este es su IMC {imc:.2f}")

resp="Tiene bajo peso" if imc<18.5 else "Tiene peso normal" if 18.5<imc<24.9 else "Tiene sobrepeso" if 25<imc<29.9 else "Tiene obesidad"
print(resp)
# Out:
# Ingrese su peso kg: 55
# Ingrese su estatura m: 1.55
# Este es su IMC 22.89
# Tiene peso normal

# %% [markdown]
# ###12

# %%
# simule una calculadora simple (+, -, *, /) con dos números.(IF-ELIF-ELSE)
numero1 = float(input("Ingresa el primer número: "))
numero2 = float(input("Ingresa el segundo número: "))
operacion = input("Ingrese la operación que desea realizar: ")

if operacion == "+":
    resultado = numero1 + numero2
    print("El resultado es:", resultado)

elif operacion == "-":
    resultado = numero1 - numero2
    print("El resultado es:", resultado)

elif operacion == "*":
    resultado = numero1 * numero2
    print("El resultado es:", resultado)

elif operacion == "/":
    if numero2 != 0:
        resultado = numero1 / numero2
        print("El resultado es:", resultado)
    else:
        print("No se puede dividir entre cero")

else:
   print("Operación no válida")
# Out:
# Ingresa el primer número: 9
# Ingresa el segundo número: 18
# Ingrese la operación que desea realizar: /
# El resultado es: 0.5

# %%
# simule una calculadora simple (+, -, *, /) con dos números.(IF-ELSE)
numero1 = float(input("Ingresa el primer número: "))
numero2 = float(input("Ingresa el segundo número: "))
operacion = input("Ingrese la operación que desea realizar: ")

if operacion == "+":
    print("Resultado:", numero1 + numero2)
else:
    if operacion == "-":
        print("Resultado:", numero1 - numero2)
    else:
        if operacion == "*":
            print("Resultado:", numero1 * numero2)
        else:
            if operacion == "/":
                if numero2 != 0:
                    print("Resultado:", numero1 / numero2)
                else:
                    print("No se puede dividir entre cero")
            else:
                print("Operación no válida")
# Out:
# Ingresa el primer número: 5
# Ingresa el segundo número: 9
# Ingrese la operación que desea realizar: +
# Resultado: 14.0

# %%
# simule una calculadora simple (+, -, *, /) con dos números.(IF TERNARIO)
numero1 = float(input("Ingresa el primer número: "))
numero2 = float(input("Ingresa el segundo número: "))
operacion = input("Ingrese la operación que desea realizar: ")

resp= "Resultado:", numero1 + numero2 if operacion == "+" else "Resultado:", numero1 - numero2 if operacion == "-" else "Resultado:", numero1 * numero2 if operacion == "*" else "Resultado:", numero1 / numero2 if operacion == "/" else "Operación no válida" if operacion != "+" and operacion != "-" and operacion != "*" and operacion != "/" else "No se puede dividir entre cero"
print(resp)
# Out:
# Ingresa el primer número: 90
# Ingresa el segundo número: 20
# Ingrese la operación que desea realizar: *
# ('Resultado:', 'Resultado:', 'Resultado:', 1800.0, 'No se puede dividir entre cero')

# %% [markdown]
# ###13

# %%
###determine la calificación en letras (A, B, C, D, F) según una nota numérica (0-100).(IF-ELIF-ELSE)
nota=int(input("Ingrese su nota: "))
if nota>=90:
  print("Su calificación tiene una: A 😄")
elif nota>=80:
  print("Su calificación tiene una: B 😊")
elif nota>=70:
  print("Su calificación tiene una: C 🙂")
elif nota>=60:
  print("Su calificación tiene una: D 🙁")
else:
  print("Su calificación tiene una: F 😖")
# Out:
# Ingrese su nota: 60
# Su calificación tiene una: D 🙁

# %%
###determine la calificación en letras (A, B, C, D, F) según una nota numérica (0-100).(IF-ELSE)
nota=int(input("Ingrese su nota: "))
if nota>=90:
  print("Su nota tiene una A 😄")
else:
  if nota>=80:
    print("Su nota tiene una B 😊")
  else:
    if nota>=70:
      print("Su nota tiene una C 🙂")
    else:
      if nota>=60:
        print("Su nota tiene una D 🙁")
      else:
        print("Su nota tiene una F 😖")
# Out:
# Ingrese su nota: 90
# Su nota tiene una A 😄

# %%
###determine la calificación en letras (A, B, C, D, F) según una nota numérica (0-100).(SI TERNARIO)
nota=int(input("Ingrese su nota: "))

resp= "Su nota tiene una A 😄" if nota>=90 else "Su nota tiene una B 😊" if nota>=80 else "Su nota tiene una C 🙂" if nota>=70 else "Su nota tiene una D 🙁" if nota>=60 else "Su nota tiene una F 😖"
print(resp)
# Out:
# Ingrese su nota: 63
# Su nota tiene una D 🙁

# %% [markdown]
# ###14

# %%
#determine el día de la semana según un número (1-7).(IF-ELIF-ELSE)
num=int(input("Ingrese un número del 1 al 7 para determinar que día de la semana es: "))
if num==1:
  print("El día es Lunes")
elif num==2:
  print("El día es Martes")
elif num==3:
  print("El día es Miércoles")
elif num==4:
  print("EL día es Jueves")
elif num==5:
  print("El día es viernes")
elif num==6:
  print("El día es Sábado")
else:
  print("El día es Domingo")
# Out:
# Ingrese un número del 1 al 7 para determinar que día de la semana es: 1
# El día es Lunes

# %%
#determine el día de la semana según un número (1-7).(IF-ELSE)
num=int(input("Ingrese un número del 1 al 7 para determinar que día de la semana es: "))
if num==1:
  print("El día es Lunes")
else:
  if num==2:
    print("El día es Martes")
  else:
    if num==3:
      print("El día es Miércoles")
    else:
      if num==4:
        print("EL día es Jueves")
      else:
        if num==5:
          print("El día es viernes")
        else:
          if num==6:
            print("El día es Sábado")
          else:
            print("El día es Domingo")
# Out:
# Ingrese un número del 1 al 7 para determinar que día de la semana es: 7
# El día es Domingo

# %%
#determine el día de la semana según un número (1-7).(SI TERNARIO)
num=int(input("Ingrese un número del 1 al 7 para determinar que día de la semana es: "))
resp="El día es Lunes" if num==1 else "El día es Martes" if num==2 else "El día es Miércoles" if num==3 else "EL día es Jueves" if num==4 else "El día es viernes" if num==5 else "El día es Sábado" if num==6 else "El día es Domingo"
print(resp)
# Out:
# Ingrese un número del 1 al 7 para determinar que día de la semana es: 5
# El día es viernes

# %% [markdown]
# ###15

# %%
#valide si tres números pueden formar un triángulo y de qué tipo es.(IF-ELIF-ELSE)

# %%
P=float(input("ingrese su peso en kg: "))
A=float(input("ingrese su altura en m: "))
IMC=P/(A**2)
if IMC<18.5:
  print("bajo peso")
elif IMC>=19.5 or IMC<=24.9:
  print("peso normal")
elif IMC>=25 or IMC<=29:
  print("sobrepeso")
else:
 print("el IMC ingresado es obesidad")

# %%
#calificaciones
n1=float(input("ingrese la nota 1: "))
n2=float(input("ingrese la nota 2: "))
n3=float(input("ingrese la nota 3: "))
n4=float(input("ingrese la nota 4: "))
f=int(input("ingrese las fallas del estudiante:"))
a=int(input("cuantas son las horas de su programa:"))
p=(n1+n2+n3)/3*.8+n4*.2
if p>=3:
  if f<=a*.2:
    print(f"Aprobó porque su nota es de {p} y asistio más del 20% de las clases")
  else:
    print(f"Reprobó porque falto {f} veces que es superior al 20%")
else:
  print("Reprobó porque su nota fue de {p}")




E=float(input("ingrese la calificación del examen:"))
if E>=3.2:
  print("Aprobó")
else:
  print("Reprobó")

# %%
C=float(input("ingrese la calificación del examen:"))
if C>=3.2:
  print("Aprobó")
else:
  print("Reprobó")
