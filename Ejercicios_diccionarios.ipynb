# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaisa290/PROGCOM-A/blob/main/Ejercicios_diccionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio 1**
# Crea un diccionario llamado frutas con tres frutas y su precio.
# Luego muestra el precio de una de ellas.
#
# Ejemplo esperado:
#
# "manzana": 2500
# "pera": 1800
# "uva": 3200

# %%
frutas={"piña":3000, "mandarina":1800, "fresa":2000}
print(f"El precio de la fresa es: {frutas['fresa']}")
print(f"El precio de la piña es: {frutas['piña']}")
print(f"El precio de la mandarina es: {frutas['mandarina']}")
# Out:
# El precio de la fresa es: 2000
# El precio de la piña es: 3000
# El precio de la mandarina es: 1800

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Ejercicio 2**
# Crea un diccionario con tres personajes de FUNPRO y su nivel.
# Después agrega un cuarto personaje.

# %%
personajes = {
    "Ingeniero": 30,
    "Alcaldesa": 100,
    "Constructor": 7
}

personajes["paladin"] = 10

print(personajes)
# Out:
# {'Ingeniero': 30, 'Alcaldesa': 100, 'Constructor': 7, 'paladin': 10}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **#Ejercicio 3**
# Crea un diccionario con el nombre de tres pociones y sus cantidades.
# Luego modifica la cantidad de una de ellas.

# %%
pociones={"Poción roja":10, "Poción verde":6, "Poción azul":15}
pociones["Poción roja"]=35
print(pociones)
# Out:
# {'Poción roja': 35, 'Poción verde': 6, 'Poción azul': 15}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Ejercicio 4
# Crea un diccionario con cuatro herramientas mágicas.
# Elimina una de ellas y muestra el resultado final.

# %%
herramientas_magicas = {
    "varita": "Lanza hechizos poderosos",
    "escoba": "Permite volar por los aires",
    "caldero": "Sirve para preparar pociones",
    "cristal": "Muestra el futuro"
}

# %%
herramientas_magicas.keys()
# Out:
# dict_keys(['varita', 'escoba', 'caldero', 'cristal'])

# %%
herramientas_magicas.values()
# Out:
# dict_values(['Lanza hechizos poderosos', 'Permite volar por los aires', 'Sirve para preparar pociones', 'Muestra el futuro'])

# %%
herramientas_magicas["varita"]
# Out:
# 'Lanza hechizos poderosos'

# %%
del herramientas_magicas["caldero"]

# %%
herramientas_magicas
# Out:
# {'varita': 'Lanza hechizos poderosos',
#  'escoba': 'Permite volar por los aires',
#  'cristal': 'Muestra el futuro'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Ejercicio 5**
# Crea un diccionario con nombres de estudiantes y sus notas.
# Muestra el promedio de todos los estudiantes y de un estudiante específico, empleando dos funciones.

# %%
estudiantes = {
    "Ana": 4.5,
    "Luis": 3.8,
    "Sofia": 4.2
}

def promedio_general(dic):
    suma = sum(dic.values())
    return suma / len(dic)

def promedio_estudiante(dic, nombre):
    return dic[nombre]

print("Promedio general:", promedio_general(estudiantes))
print("Nota de Ana:", promedio_estudiante(estudiantes, "Ana"))
# Out:
# Promedio general: 4.166666666666667
# Nota de Ana: 4.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Ejercicio 6**
# Verifica si la clave "hechicero" existe en un diccionario de personajes.
# Si existe, muestra su información; si no existe, imprime un mensaje de advertencia.

# %%
personajes = {
    "guerrero": 20,
    "arquero": 15
}

if "hechicero" in personajes:
    print(personajes["hechicero"])
else:
    print("El hechicero no existe")
# Out:
# El hechicero no existe

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Ejercicio 7**
# Dada la palabra "magia", cuenta cuántas veces aparece cada letra usando un diccionario.
#
# Pista:
# Recorre la palabra letra por letra y ve acumulando el conteo.

# %%
palabra = "magia"
conteo = {}

for letra in palabra:
    if letra in conteo:
        conteo[letra] += 1
    else:
        conteo[letra] = 1

print(conteo)
# Out:
# {'m': 1, 'a': 2, 'g': 1, 'i': 1}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Ejercicio 8**
# Dada una lista de elementos recolectados en una expedición, cuenta cuántas veces aparece cada elemento.
#
# Lista sugerida: ["gema", "oro", "gema", "madera", "oro", "oro", "gema"]

# %%
lista = ["gema", "oro", "gema", "madera", "oro", "oro", "gema"]
conteo = {}

for item in lista:
    if item in conteo:
        conteo[item] += 1
    else:
        conteo[item] = 1

print(conteo)
# Out:
# {'gema': 3, 'oro': 3, 'madera': 1}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Ejercicio 9**
# Desarrolla el ejercicio de la floristería (el desarrolladdo con listas) pero empleando diccionarios.

# %%
flores = {
    "rosa": 10,
    "tulipan": 5,
    "girasol": 8
}

# vender una rosa
flores["rosa"] -= 1

# agregar nuevas flores
flores["orquidea"] = 6

print(flores)
# Out:
# {'rosa': 9, 'tulipan': 5, 'girasol': 8, 'orquidea': 6}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Ejercicio 10**
# Simula un pequeño inventario.
# Debes permitir:
#
# agregar un objeto,
# actualizar la cantidad de un objeto,
# eliminar un objeto,
# mostrar el inventario final.

# %%
inventario = {}

inventario["espada"] = 1
inventario["escudo"] = 2
inventario["espada"] = 3
del inventario["escudo"]

print("Inventario final:", inventario)
# Out:
# Inventario final: {'espada': 3}

# %% [markdown]
# ![image.png](data:image/png;base64,...)
